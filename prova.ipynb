# %%
from datetime import datetime
import pandas as pd
from alpaca.data.historical import CryptoHistoricalDataClient,StockHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest,StockBarsRequest
from alpaca.data.timeframe import TimeFrame

apikey = 'PK2IYOWEIRSXWD3ZLYXEDMZ4PA'
secret_key = '6YtbRbzfAJHAic6og9x35v2fvuxyBQzKeAsaTeH8K9dx'

endpoint = 'https://paper-api.alpaca.markets/v2'

# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import GetAssetsRequest
import hayai_util

context = hayai_util.create_context('medium_tech_usa')

trading_client = TradingClient(context['api_key'], context['secret_key'], paper=True)

# Get our account information.
account = trading_client.get_account()

# Check if our account is restricted from trading.
if account.trading_blocked:
    print('Account is currently restricted from trading.')

# Check how much money we can use to open new positions.
print('${} is available as buying power.'.format(account.buying_power))
account
# Out:
# $199012.2 is available as buying power.
# {   'account_blocked': False,
#     'account_number': 'PA3KM7I3YKDN',
#     'accrued_fees': '0',
#     'buying_power': '199012.2',
#     'cash': '99947.53',
#     'created_at': datetime.datetime(2026, 2, 22, 15, 18, 10, 188300, tzinfo=TzInfo(0)),
#     'crypto_status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'currency': 'USD',
#     'daytrade_count': 0,
#     'daytrading_buying_power': '0',
#     'equity': '99986.29',
#     'id': UUID('ec53c810-895b-46ba-97ea-9814fbd99da1'),
#     'initial_margin': '480.19',
#     'last_equity': '99986.9452501177',
#     'last_maintenance_margin': '288.29',
#     'long_market_value': '499.57',
#     'maintenance_margin': '288.11',
#     'multiplier': '2',
#     'non_marginable_buying_power': '99486.72',
#     'options_approved_level': 3,
#     'options_buying_power': '99506.1',
#     'options_trading_level': 3,
#     'pattern_day_trader': False,
#     'pending_transfer_in': None,
#     'pending_transfer_out': None,
#     'portfolio_value': '99986.29',
#     'regt_buying_power': '199012.2',
#     'short_market_value': '-460.81',
#     'shorting_enabled': True,
#     'sma': '99999.63',
#     'status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
#     'transfers_blocked': False}

# %%
# Get a list of all of our positions.
portfolio = trading_client.get_all_positions()

df = pd.DataFrame([position.__dict__ for position in portfolio])
df.head(5)
# Out:
#                                asset_id symbol exchange asset_class  \
# 0  93c9d209-0a8f-4a9a-b6af-66876bcfcbeb   ALRM   NASDAQ   us_equity
# 1  a33fb18b-cb85-4c58-b45d-2f68a2d7cee2    BOX     NYSE   us_equity
# 2  18de2675-4e77-46a0-b388-b64b7b2a8ee3   CSGS   NASDAQ   us_equity
# 3  001b756f-8941-4884-af8a-f5f81e14d229   CWAN     NYSE   us_equity
# 4  56288839-5e01-474f-9501-2d392fee0cf6   DIOD   NASDAQ   us_equity
#
#    asset_marginable avg_entry_price          qty   side market_value  \
# 0              True            46.8           -2  short       -97.38
# 1              True           22.95           -4  short        -95.6
# 2              True           79.77  1.252818842   long   100.075169
# 3              True            23.5           -4  short       -93.72
# 4              True           70.77  1.443209698   long   100.490691
#
#   cost_basis  ... unrealized_plpc unrealized_intraday_pl  \
# 0      -93.6  ...        -0.04038                      0
# 1      -91.8  ...        -0.04139                      0
# 2  99.937359  ...         0.00138                      0
# 3        -94  ...         0.00298                   0.12
# 4  102.13595  ...        -0.01611                      0
#
#   unrealized_intraday_plpc current_price lastday_price change_today swap_rate  \
# 0                        0         48.69         48.69            0      None
# 1                        0          23.9          23.9            0      None
# 2                        0         79.88         79.88            0      None
# 3                  0.00128         23.43         23.46     -0.00128      None
# 4                        0         69.63         69.63            0      None
#
#   avg_entry_swap_rate   usd qty_available
# 0                None  None            -2
# 1                None  None            -4
# 2                None  None   1.252818842
# 3                None  None            -4
# 4                None  None   1.443209698
#
# [5 rows x 21 columns]

# %%
aapl_position = trading_client.get_open_position('BOX')
aapl_position
# Out:
# {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('a33fb18b-cb85-4c58-b45d-2f68a2d7cee2'),
#     'asset_marginable': True,
#     'avg_entry_price': '22.95',
#     'avg_entry_swap_rate': None,
#     'change_today': '0',
#     'cost_basis': '-91.8',
#     'current_price': '23.9',
#     'exchange': <AssetExchange.NYSE: 'NYSE'>,
#     'lastday_price': '23.9',
#     'market_value': '-95.6',
#     'qty': '-4',
#     'qty_available': '-4',
#     'side': <PositionSide.SHORT: 'short'>,
#     'swap_rate': None,
#     'symbol': 'BOX',
#     'unrealized_intraday_pl': '0',
#     'unrealized_intraday_plpc': '0',
#     'unrealized_pl': '-3.8',
#     'unrealized_plpc': '-0.04139',
#     'usd': None}
