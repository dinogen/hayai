# %%
from datetime import datetime
import pandas as pd
from alpaca.data.historical import StockHistoricalDataClient,CryptoHistoricalDataClient
from alpaca.data.requests import StockLatestTradeRequest,StockBarsRequest,CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import GetAssetsRequest
import hayai_util
context = hayai_util.create_context('medium_tech_usa')
crypto_client = CryptoHistoricalDataClient(context['api_key'], context['secret_key'])
trading_client = TradingClient(context['api_key'], context['secret_key'], paper=True)

# %%
# Get our account information.
account = trading_client.get_account()

# Check if our account is restricted from trading.
if account.trading_blocked:
    print('Account is currently restricted from trading.')

# Check how much money we can use to open new positions.
print('${} is available as buying power.'.format(account.buying_power))
account

# %%
# Get a list of all of our positions.
portfolio = trading_client.get_all_positions()

df = pd.DataFrame([position.__dict__ for position in portfolio])
df['qty'] = df['qty'].astype(float)
df['market_value'] = df['market_value'].astype(float)
df['current_price'] = df['current_price'].astype(float)
df = df[['symbol', 'qty', 'market_value', 'current_price']]
df['market_value'].sum(),df[df['market_value']>0]['market_value'].sum(),df[df['market_value']<0]['market_value'].sum()

# %% [markdown]
# Prezzo quando compro: ask
# Prezzo quando vendo: bid
# Usare la media dei due

# %%
lsr = StockLatestTradeRequest(symbol_or_symbols=['AAPL', 'MSFT', 'GOOG'])
client = StockHistoricalDataClient(context['api_key'], context['secret_key'])
result =client.get_stock_latest_trade(lsr)
pd.DataFrame(result)

# %%
prices = {k: v.price for k, v in result.items()}
pd.DataFrame(list(prices.items()), columns=['symbol', 'price'])

# %%
account = trading_client.get_account()
account

# %%
import yfinance as yf
symbols = ['GBPUSD=X', 'EURUSD=X', 'USDJPY=X', 'USDCAD=X', 'USDCHF=X', 'AUDUSD=X', 'NZDUSD=X','GC=F']
data = yf.download(symbols, period="5y", interval="1d")
df = data['Close']
df.columns = [col.split('=')[0] for col in df.columns]
df
# Out:
# [*********************100%***********************]  8 of 8 completed
#               AUDUSD    EURUSD    GBPUSD           GC    NZDUSD   USDCAD  \
# Date
# 2021-03-08  0.770910  1.192563  1.385368  1677.699951  0.717860  1.26319
# 2021-03-09  0.765667  1.185171  1.382361  1716.599976  0.713262  1.26579
# 2021-03-10  0.771784  1.189791  1.389043  1721.500000  0.717958  1.26431
# 2021-03-11  0.773200  1.192606  1.393146  1722.300049  0.719217  1.26201
# 2021-03-12  0.778762  1.198610  1.398993  1719.500000  0.722752  1.25314
# ...              ...       ...       ...          ...       ...      ...
# 2026-03-03  0.710580  1.169727  1.341058  5107.399902  0.594880  1.36710
# 2026-03-04  0.704070  1.161224  1.335363  5120.200195  0.588911  1.36741
# 2026-03-05  0.707600  1.163562  1.336952  5065.299805  0.593761  1.36440
# 2026-03-06  0.701130  1.160807  1.335738  5146.100098  0.589769  1.36699
# 2026-03-07  0.703284       NaN  1.341292          NaN  0.590214  1.35670
#
#              USDCHF      USDJPY
# Date
# 2021-03-08  0.93020  108.418999
# 2021-03-09  0.93580  108.939003
# 2021-03-10  0.92814  108.577003
# 2021-03-11  0.92970  108.431999
# 2021-03-12  0.92466  108.555000
# ...             ...         ...
# 2026-03-03  0.77871  157.257004
# 2026-03-04  0.78192  157.772995
# 2026-03-05  0.77915  156.983002
# 2026-03-06  0.78066  157.533997
# 2026-03-07      NaN         NaN
#
# [1302 rows x 8 columns]

# %%
df.reset_index().info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1302 non-null   datetime64[s]
#  1   AUDUSD  1301 non-null   float64
#  2   EURUSD  1300 non-null   float64
#  3   GBPUSD  1301 non-null   float64
#  4   GC      1258 non-null   float64
#  5   NZDUSD  1301 non-null   float64
#  6   USDCAD  1301 non-null   float64
#  7   USDCHF  1300 non-null   float64
#  8   USDJPY  1300 non-null   float64
# dtypes: datetime64[s](1), float64(8)
# memory usage: 91.7 KB
